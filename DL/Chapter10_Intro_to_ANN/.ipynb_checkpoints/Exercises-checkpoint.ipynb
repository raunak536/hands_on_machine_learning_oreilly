# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# C:\Users\rauna\Anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
(x_train_full, y_train_full), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train_full.shape, y_train_full.shape, x_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
x_train, y_train = x_train_full[:-5000] / 255., y_train_full[:-5000]
x_valid, y_valid = x_train_full[-5000:] / 255., y_train_full[-5000:]
x_test = x_test / 255.

# %%
x_train.shape, y_train.shape, x_valid.shape, y_valid.shape, x_test.shape, y_test.shape
# Out:
# ((55000, 28, 28), (55000,), (5000, 28, 28), (5000,), (10000, 28, 28), (10000,))

# %% [markdown]
# ---

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Input(shape=(28, 28)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(300, activation='relu'))
model.add(tf.keras.layers.Dense(100, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6210 - accuracy: 0.8388 - val_loss: 0.2619 - val_accuracy: 0.9328
# Epoch 2/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2971 - accuracy: 0.9148 - val_loss: 0.2148 - val_accuracy: 0.9384
# Epoch 3/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2439 - accuracy: 0.9296 - val_loss: 0.1793 - val_accuracy: 0.9532
# Epoch 4/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.2083 - accuracy: 0.9400 - val_loss: 0.1576 - val_accuracy: 0.9562
# Epoch 5/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.1810 - accuracy: 0.9479 - val_loss: 0.1392 - val_accuracy: 0.9644
# Epoch 6/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.1602 - accuracy: 0.9541 - val_loss: 0.1297 - val_accuracy: 0.9662
# Epoch 7/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.1425 - accuracy: 0.9589 - val_loss: 0.1169 - val_accuracy: 0.9698
# Epoch 8/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.1279 - accuracy: 0.9636 - val_loss: 0.1142 - val_accuracy: 0.9702
# Epoch 9/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.1167 - accuracy: 0.9667 - val_loss: 0.1089 - val_accuracy: 0.9712
# Epoch 10/10
# 1719/1719 [==============================] - 4s 2ms/step - loss: 0.1059 - accuracy: 0.9698 - val_loss: 0.0997 - val_accuracy: 0.9738

# %%
df_history = pd.DataFrame(history.history)

# %%
df_history.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.619985  0.840091  0.255102        0.9352
# 1  0.291666  0.917164  0.207101        0.9440
# 2  0.238055  0.932182  0.169511        0.9560
# 3  0.202785  0.941927  0.151553        0.9616
# 4  0.176368  0.949727  0.133347        0.9658

# %%
sns.lineplot(data=df_history, x=df_history.index, y='loss')
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
